# %% [markdown]
# # Imports

# %%
from hipscatalog_gen.config import load_config_from_dict, display_available_configs
from hipscatalog_gen.pipeline import run_pipeline

# %% [markdown]
# # Configs

# %%
display_available_configs()

# %%
cfg = {
    "input": {
        "paths": ["../../../hipscatalog_gen/examples/data/des_dr2_small_sample/*.parquet"],
    },
    "columns": {
        "ra": "RA",
        "dec": "DEC",
        "score": "MAG_AUTO_I_DERED",
    },
    "algorithm": {"level_limit": 8},
    "cluster": {},
    "output": {
        "out_dir": "../../../hipscatalog_gen/outputs/DES_DR2_small_sample",
        "cat_name": "DES_DR2_small_sample",
    },
}

cfg = load_config_from_dict(cfg)

# %% [markdown]
# # Run the pipeline

# %%
run_pipeline(cfg)
